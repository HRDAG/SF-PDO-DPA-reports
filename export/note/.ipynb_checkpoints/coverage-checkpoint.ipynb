# %%
# dependencies
import re
import pandas as pd
from plotnine import (
    ggplot,
    aes,
    after_stat,
    geom_bar,
    geom_text
)
import plotnine

# %%
# support methods

# %%
# main
complaints = pd.read_parquet("../../clean/output/complaints.parquet")

# %% [markdown]
# # DPA not OCC
# The dataset used here includes records processed from both Department of Police Accountability reports and the Office Citizen Complaints reports.
# - DPA began in 2016, so reports from that year onward should all be from DPA
# - monthly OCC reports going back to 2005 can be found on the [wayback archive](https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/reports-statistics#2012). For some reason, reports for 2010, 2011, and 2012 are not being scraped well?

# %% [markdown]
# ### review of fields

# %%
[col for col in complaints.columns if 'date' in col]
# Out:
# ['date_complained',
#  'date_completed',
#  'easy_date_complained',
#  'easy_date_completed']

# %%
complaints[[col for col in complaints.columns if 'date' in col]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26011 entries, 0 to 26990
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date_complained       25809 non-null  object
#  1   date_completed        25830 non-null  object
#  2   easy_date_complained  25764 non-null  datetime64[ns]
#  3   easy_date_completed   25783 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), object(2)
# memory usage: 1016.1+ KB

# %% [markdown]
# ## range of dates extracted

# %%
complaints.easy_date_complained.describe()
# Out:
# count                            25764
# mean     2012-07-03 11:51:43.679552768
# min                2001-07-17 00:00:00
# 25%                2006-12-26 18:00:00
# 50%                2013-09-06 00:00:00
# 75%                2017-08-31 00:00:00
# max                2023-06-07 00:00:00
# Name: easy_date_complained, dtype: object

# %%
complaints.easy_date_completed.describe()
# Out:
# count                            25783
# mean     2013-02-25 03:46:01.680176896
# min                2004-12-31 00:00:00
# 25%                2007-08-01 00:00:00
# 50%                2014-04-30 00:00:00
# 75%                2018-04-19 00:00:00
# max                2023-06-23 00:00:00
# Name: easy_date_completed, dtype: object

# %% [markdown]
# ## coverage of formatting method

# %%
complaints.easy_date_complained.notna().sum()
# Out:
# 25764

# %%
complaints.easy_date_complained.notna().sum() / complaints.shape[0]
# Out:
# 0.9905040175310446

# %%
complaints.easy_date_completed.notna().sum()
# Out:
# 25783

# %%
complaints.easy_date_completed.notna().sum() / complaints.shape[0]
# Out:
# 0.9912344777209642

# %% [markdown]
# ## OOB datestamps?

# %%
assert not any(complaints.easy_date_complained.dt.year > 2023)

# %%
assert not any(complaints.easy_date_completed.dt.year > 2023)

# %% [markdown]
# ## missing datestamps?

# %%
complaints.date_complained.isna().sum()
# Out:
# 202

# %%
complaints.loc[(complaints.date_complained.notna()) & (complaints.easy_date_complained.isna()), 
['date_complained', 'pdf_url']].values
# Out:
# array([['06/17/022',
#         'https://sf.gov/sites/default/files/2023-03/Openness_report_Jan_23.pdf'],
#        ['06/17/022',
#         'https://sf.gov/sites/default/files/2023-03/Openness_report_Jan_23.pdf'],
#        ['12/01/022',
#         'https://sf.gov/sites/default/files/2023-07/Openness%20May.pdf'],
#        ['01/027/22',
#         'https://sf.gov/sites/default/files/2022-04/DPA_02_22_openness_0.pdf'],
#        ['02/1422',
#         'https://sf.gov/sites/default/files/2022-06/DPA_05_22_openness_0.pdf'],
#        ['043/05/22',
#         'https://sf.gov/sites/default/files/2023-04/Openness%20Nov.pdf'],
#        ['043/05/22',
#         'https://sf.gov/sites/default/files/2023-04/Openness%20Nov.pdf'],
#        ['04/06/022',
#         'https://sf.gov/sites/default/files/2023-01/openness%20dec.xlsx.pdf'],
#        ['04/06/022',
#         'https://sf.gov/sites/default/files/2023-01/openness%20dec.xlsx.pdf'],
#        ['04/06/022',
#         'https://sf.gov/sites/default/files/2023-01/openness%20dec.xlsx.pdf'],
#        ['04/88/21',
#         'https://sf.gov/sites/default/files/2021-07/DPA_04_21_openness.pdf'],
#        ['09/21/0',
#         'https://sf.gov/sites/default/files/2021-08/DPA_06_21_openness.pdf'],
#        ['06/15/0',
#         'https://sf.gov/sites/default/files/2021-08/DPA_06_21_openness.pdf'],
#        ['08/05',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/sites/default/files/DPA_10_19_openness.pdf'],
#        ['08/05',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/sites/default/files/DPA_10_19_openness.pdf'],
#        ['02/02/8',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/sites/default/files/DPA_08_18_openness.pdf'],
#        ['02/02/8',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/sites/default/files/DPA_08_18_openness.pdf'],
#        ['07/31/8',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/sites/default/files/DPA_08_18_openness.pdf'],
#        ['08/22018',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/sites/default/files/DPA_09_18_openness.pdf'],
#        ['03/03/6',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/sites/default/files/DPA_02_17_openness.pdf'],
#        ['03/03/6',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/sites/default/files/DPA_02_17_openness.pdf'],
#        ['0/07/15',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/sites/default/files/DPA_08_17_openness.pdf'],
#        ['112/21/09',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_04_09_openness.pdf'],
#        ['112/21/09',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_04_09_openness.pdf'],
#        ['04/12//06',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_03_07_openness.pdf'],
#        ['04/12//06',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_03_07_openness.pdf'],
#        ['08/11//05',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_03_07_openness.pdf'],
#        ['08/11//05',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_03_07_openness.pdf'],
#        ['10/17//06',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_03_07_openness.pdf'],
#        ['10/17//06',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_03_07_openness.pdf'],
#        ['10/25//06',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_03_07_openness.pdf'],
#        ['11/10//05',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_03_07_openness.pdf'],
#        ['11/10//05',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_03_07_openness.pdf'],
#        ['0/15/07',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_05_07_openness.pdf'],
#        ['0/15/07',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_05_07_openness.pdf'],
#        ['03/22//07',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_06_07_openness.pdf'],
#        ['03/22//07',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_06_07_openness.pdf'],
#        ['12/05//06',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_09_07_openness.pdf'],
#        ['12/05//06',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_09_07_openness.pdf'],
#        ['01/12//05',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_02_05_openness.pdf'],
#        ['01/12//05',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_02_05_openness.pdf'],
#        ['05/12//05',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_09_05_openness.pdf'],
#        ['05/12//05',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_09_05_openness.pdf'],
#        ['03/15//05',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_11_05_openness.pdf'],
#        ['03/15//05',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_11_05_openness.pdf']],
#       dtype=object)

# %%
complaints.date_completed.isna().sum()
# Out:
# 181

# %%
complaints.loc[(complaints.date_completed.notna()) & (complaints.easy_date_completed.isna()), 
['date_completed', 'pdf_url']].values
# Out:
# array([['04/06/023',
#         'https://sf.gov/sites/default/files/2023-05/Openness%20April.pdf'],
#        ['0/09/22',
#         'https://sf.gov/sites/default/files/2022-04/DPA_02_22_openness_0.pdf'],
#        ['11/01//22',
#         'https://sf.gov/sites/default/files/2023-04/Openness%20Nov.pdf'],
#        ['01//11/21',
#         'https://sf.gov/sites/default/files/2021-07/DPA_01_21_openness.pdf'],
#        ['01//11/21',
#         'https://sf.gov/sites/default/files/2021-07/DPA_01_21_openness.pdf'],
#        ['03/22/2',
#         'https://sf.gov/sites/default/files/2021-07/DPA_03_21_openness.pdf'],
#        ['03/22/2',
#         'https://sf.gov/sites/default/files/2021-07/DPA_03_21_openness.pdf'],
#        ['0708/21',
#         'https://sf.gov/sites/default/files/2021-08/DPA_07_21_openness.pdf'],
#        ['0708/21',
#         'https://sf.gov/sites/default/files/2021-08/DPA_07_21_openness.pdf'],
#        ['1012/21',
#         'https://sf.gov/sites/default/files/2021-12/Openness%20Report_DPA%20October%202021_120621.pdf'],
#        ['01//16/2020',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/sites/default/files/DPA_01_20_openness.pdf'],
#        ['0/12/2020',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/sites/default/files/DPA_02_20_openness.pdf'],
#        ['0/12/2020',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/sites/default/files/DPA_02_20_openness.pdf'],
#        ['0/12/2020',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/sites/default/files/DPA_02_20_openness.pdf'],
#        ['0/12/2020',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/sites/default/files/DPA_02_20_openness.pdf'],
#        ['0/12/2020',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/sites/default/files/DPA_02_20_openness.pdf'],
#        ['10/;21/20',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/sites/default/files/DPA_10_20_openness.pdf'],
#        ['07/06',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/sites/default/files/DPA_07_18_openness.pdf'],
#        ['12/17',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/sites/default/files/DPA_12_18_openness.pdf'],
#        ['02//27/14',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/sites/default/files/OCC_02_14_openness.pdf'],
#        ['01/10//09',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_01_09_openness.pdf'],
#        ['01/10//09',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_01_09_openness.pdf'],
#        ['01//05/09',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_01_09_openness.pdf'],
#        ['04//09/09',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_04_09_openness.pdf'],
#        ['04//09/09',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_04_09_openness.pdf'],
#        ['06/04//09',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_06_09_openness.pdf'],
#        ['12/11//09',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_12_09_openness.pdf'],
#        ['03/10//08',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_03_08_openness.pdf'],
#        ['03/10//08',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_03_08_openness.pdf'],
#        ['08/12//08',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_08_08_openness.pdf'],
#        ['12/12//08',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_12_08_openness.pdf'],
#        ['12/12//08',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_12_08_openness.pdf'],
#        ['03/03//07',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_03_07_openness.pdf'],
#        ['03/03//07',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_03_07_openness.pdf'],
#        ['04/04//07',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_04_07_openness.pdf'],
#        ['04/04//07',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_04_07_openness.pdf'],
#        ['04/04//07',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_04_07_openness.pdf'],
#        ['04/04//07',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_04_07_openness.pdf'],
#        ['04/18//07',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_04_07_openness.pdf'],
#        ['04/18//07',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_04_07_openness.pdf'],
#        ['06/0707',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_06_07_openness.pdf'],
#        ['06/0707',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_06_07_openness.pdf'],
#        ['03/16//06',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_03_06_openness.pdf'],
#        ['03/16//06',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_03_06_openness.pdf'],
#        ['03/31//06',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_03_06_openness.pdf'],
#        ['02/09//05',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_02_05_openness.pdf'],
#        ['02/09//05',
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_02_05_openness.pdf']],
#       dtype=object)

# %% [markdown]
# ## time to close

# %%
complaints.ttc_group.value_counts()
# Out:
# ttc_group
# Under 1 year      12329
# Under 6 months     4463
# Under 3 months     3330
# Under 2 years      2940
# Under 1 month      1874
# Over 2 years        530
# NEGATIVE            207
# Name: count, dtype: int64

# %%
complaints.time_to_complete.describe()
# Out:
# count                          25673
# mean     240 days 15:48:45.797530480
# std      208 days 13:01:12.887090120
# min             -3135 days +00:00:00
# 25%                109 days 00:00:00
# 50%                232 days 00:00:00
# 75%                323 days 00:00:00
# max               2805 days 00:00:00
# Name: time_to_complete, dtype: object

# %%
complaints.loc[complaints.ttc_group.str.contains("month", na=False)].shape[0] / complaints.shape[0]
# Out:
# 0.37165045557648685

# %%
complaints.loc[complaints.ttc_group.str.contains("year", na=False)].shape[0] / complaints.shape[0]
# Out:
# 0.6073968705547653

# %%
subset = complaints[['allegation_id', 'year_complained', 'ttc_group']].copy().set_index('allegation_id')
ohe = pd.get_dummies(subset.ttc_group)
df = pd.merge(subset, ohe, on='allegation_id')
df.drop(columns=['ttc_group', 'NEGATIVE'], inplace=True)
gb = df.groupby('year_complained').sum()
gb
# Out:
#                  Over 2 years  Under 1 month  Under 1 year  Under 2 years  \
# year_complained
# 2001.0                     18              0             0              0
# 2002.0                     44              0             0              0
# 2003.0                     36              0             0             34
# 2004.0                     15              6           978            213
# 2005.0                     62            136          1323            418
# 2006.0                     38            142           780            429
# 2007.0                      0            183           865            295
# 2008.0                      0            216          1045             70
# 2009.0                      0            157           437              0
# 2010.0                      0              5             0              0
# 2011.0                     47              0             0              0
# 2012.0                      6              0             0             19
# 2013.0                      6              2           778             82
# 2014.0                     44            110          1051            180
# 2015.0                     86            114           808            482
# 2016.0                      6             82           861            310
# 2017.0                     15             77           618             70
# 2018.0                     16            108           706             78
# 2019.0                     52            126           635            118
# 2020.0                     31            114           595             44
# 2021.0                      8            145           437             87
# 2022.0                      0            114           412             11
# 2023.0                      0             37             0              0
#
#                  Under 3 months  Under 6 months
# year_complained
# 2001.0                        0               0
# 2002.0                        0               0
# 2003.0                        0               0
# 2004.0                       39             136
# 2005.0                      389             470
# 2006.0                      293             439
# 2007.0                      446             430
# 2008.0                      419             458
# 2009.0                      370             453
# 2010.0                        0               0
# 2011.0                        0               0
# 2012.0                        0               0
# 2013.0                       30             102
# 2014.0                      163             277
# 2015.0                       99             214
# 2016.0                      110             120
# 2017.0                       94             163
# 2018.0                      168             242
# 2019.0                      182             275
# 2020.0                      155             259
# 2021.0                      132             166
# 2022.0                      165             242
# 2023.0                       76              17

# %%
less = complaints[['year_complained', 'year_completed', 'ttc_group', 'time_to_complete']].dropna()
less = less.loc[less.ttc_group != 'NEGATIVE']
less
# Out:
#        year_complained  year_completed       ttc_group time_to_complete
# 0               2021.0          2023.0   Under 2 years         467 days
# 1               2021.0          2023.0   Under 2 years         467 days
# 2               2021.0          2023.0   Under 2 years         467 days
# 3               2021.0          2023.0   Under 2 years         467 days
# 4               2021.0          2023.0   Under 2 years         467 days
# ...                ...             ...             ...              ...
# 26986           2005.0          2005.0  Under 3 months          50 days
# 26987           2005.0          2005.0  Under 3 months          65 days
# 26988           2005.0          2005.0  Under 3 months          65 days
# 26989           2005.0          2005.0  Under 3 months          53 days
# 26990           2005.0          2005.0  Under 3 months          53 days
#
# [25466 rows x 4 columns]

# %%
(ggplot(less.dropna(), aes('year_complained', fill='ttc_group'))
 + geom_bar()
)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/utils.py:1183: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/utils.py:289: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/stats/stat_count.py:70: FutureWarning: The provided callable <function sum at 0x1052da340> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/stats/stat_count.py:70: FutureWarning: The provided callable <function sum at 0x1052da340> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/stats/stat_count.py:70: FutureWarning: The provided callable <function sum at 0x1052da340> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/stats/stat_count.py:70: FutureWarning: The provided callable <function sum at 0x1052da340> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/stats/stat_count.py:70: FutureWarning: The provided callable <function sum at 0x1052da340> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/stats/stat_count.py:70: FutureWarning: The provided callable <function sum at 0x1052da340> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/mizani/scale.py:210: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/mizani/scale.py:223: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# <Figure Size: (640 x 480)>

# %%
scatter5 = plotnine.qplot(x="year_complained",y="time_to_complete", data=less, geom="point", color="factor(ttc_group)",
                          xlab="year investigation completed", ylab="time to complete",
                          main="Length of Investigation by Year Complained"
                         )
scatter5
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/utils.py:1183: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/utils.py:289: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/mizani/scale.py:210: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/mizani/scale.py:223: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# <Figure Size: (640 x 480)>

# %%
(ggplot(less.dropna(), aes('year_completed', fill='ttc_group'))
 + geom_bar()
)
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/utils.py:1183: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/utils.py:289: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/stats/stat_count.py:70: FutureWarning: The provided callable <function sum at 0x123ada340> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/stats/stat_count.py:70: FutureWarning: The provided callable <function sum at 0x123ada340> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/stats/stat_count.py:70: FutureWarning: The provided callable <function sum at 0x123ada340> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/stats/stat_count.py:70: FutureWarning: The provided callable <function sum at 0x123ada340> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/stats/stat_count.py:70: FutureWarning: The provided callable <function sum at 0x123ada340> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/stats/stat_count.py:70: FutureWarning: The provided callable <function sum at 0x123ada340> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass 'sum' instead.
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/mizani/scale.py:210: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/mizani/scale.py:223: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# <Figure Size: (640 x 480)>

# %%
scatter5 = plotnine.qplot(x="year_completed",y="time_to_complete", data=less, geom="point", color="factor(ttc_group)",
                          xlab="year investigation completed", ylab="time to complete",
                          main="Length of Investigation by Year Completed"
                         )
scatter5
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/utils.py:1183: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/utils.py:289: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/mizani/scale.py:210: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/mizani/scale.py:223: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# <Figure Size: (640 x 480)>

# %%
chart = ggplot(data=less, mapping=aes(x="year_completed", y="time_to_complete", size="ttc_group"))
points = plotnine.geom_point(alpha=0.25, color='purple')
labels = plotnine.labs(x="year", y="time to complete", 
                       title="time to complete investigation by year completed", size="ttc_group")
theme_grammer = plotnine.theme(figure_size=(10,7))
scatter4 = chart + points + labels + theme_grammer
scatter4
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/utils.py:1183: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/scales/scale_size.py:49: PlotnineWarning: Using size for a discrete variable is not advised.
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/utils.py:289: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/mizani/scale.py:210: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/mizani/scale.py:223: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# <Figure Size: (1000 x 700)>

# %%
chart = ggplot(data=less, mapping=aes(x="year_completed", y="time_to_complete"))
points = plotnine.geom_jitter(alpha=0.25, color='purple')
labels = plotnine.labs(x="year", y="time to complete", 
                       title="time to complete investigation by year completed")
theme_grammer = plotnine.theme(figure_size=(10,7))
scatter4 = chart + points + labels + theme_grammer
scatter4
# Out:
# /opt/homebrew/Caskroom/miniforge/base/lib/python3.11/site-packages/plotnine/utils.py:1183: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# <Figure Size: (1000 x 700)>

# %% [markdown]
# ## negative time to close??

# %%
complaints.loc[(complaints.ttc_group == 'NEGATIVE') & (~complaints.pdf_url.str.contains("June_Openness", regex=False)), 
['date_complained', 'date_completed', 'easy_date_complained', 'easy_date_completed', 'pdf_url']].values
# Out:
# array([['04/26/22', '01/10/22', Timestamp('2022-04-26 00:00:00'),
#         Timestamp('2022-01-10 00:00:00'),
#         'https://sf.gov/sites/default/files/2022-04/DPA_01_22_openness_0.pdf'],
#        ['09/01/21', '02/09/21', Timestamp('2021-09-01 00:00:00'),
#         Timestamp('2021-02-09 00:00:00'),
#         'https://sf.gov/sites/default/files/2022-04/DPA_02_22_openness_0.pdf'],
#        ['08/24/22', '05/15/22', Timestamp('2022-08-24 00:00:00'),
#         Timestamp('2022-05-15 00:00:00'),
#         'https://sf.gov/sites/default/files/2022-06/DPA_05_22_openness_0.pdf'],
#        ...,
#        ['05/10/06', '04/24/06', Timestamp('2006-05-10 00:00:00'),
#         Timestamp('2006-04-24 00:00:00'),
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_04_06_openness.pdf'],
#        ['05/10/06', '04/24/06', Timestamp('2006-05-10 00:00:00'),
#         Timestamp('2006-04-24 00:00:00'),
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_04_06_openness.pdf'],
#        ['06/14/05', '03/21/05', Timestamp('2005-06-14 00:00:00'),
#         Timestamp('2005-03-21 00:00:00'),
#         'https://wayback.archive-it.org/org-571/20230120175459/https://sfgov.org/dpa/ftp/uploadedfiles/occ/OCC_03_05_openness.pdf']],
#       dtype=object)

# %%
complaints.loc[(complaints.ttc_group == 'NEGATIVE') & (complaints.pdf_url.str.contains("June_Openness", regex=False)), 
['date_complained', 'date_completed', 'easy_date_complained', 'easy_date_completed', 'pdf_url']].values
# Out:
# array([['12/15/22', '06/05/22', Timestamp('2022-12-15 00:00:00'),
#         Timestamp('2022-06-05 00:00:00'),
#         'https://sf.gov/sites/default/files/2023-07/June_Openness.pdf'],
#        ['12/15/22', '06/05/22', Timestamp('2022-12-15 00:00:00'),
#         Timestamp('2022-06-05 00:00:00'),
#         'https://sf.gov/sites/default/files/2023-07/June_Openness.pdf'],
#        ['12/15/22', '06/05/22', Timestamp('2022-12-15 00:00:00'),
#         Timestamp('2022-06-05 00:00:00'),
#         'https://sf.gov/sites/default/files/2023-07/June_Openness.pdf']],
#       dtype=object)

# %% [markdown]
# - these are definitely all typos. some are salvageable (for example, the set from the June 2023 report uses 2022 in the date completed field accidentally for some pages of some complaints), but some may be too difficult to recover (unknown true date complained)
# - we can likely make informated corrections to the date_completed field most of the time using common sense and metadata, but highly unlikely date_complained can be corrected with the same methods (or at all)
# - per TS, we can definitely salvage partial datestamps using any valid day/month/year combo, noting that it's probably day we will be missing (at least as far as date_completed goes)
