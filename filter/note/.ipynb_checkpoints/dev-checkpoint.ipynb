# %%
# dependencies
import pandas as pd

# %%
# support methods

# %%
# main
ref = pd.read_parquet("../../segment/output/reference-table.parquet")
ref.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30630 entries, 0 to 30629
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   pdf_url                30630 non-null  object
#  1   pdf_file               30630 non-null  object
#  2   fileid                 30630 non-null  object
#  3   complaint_no           30630 non-null  int64
#  4   complaint_meta         30446 non-null  object
#  5   allegation_no          30630 non-null  int64
#  6   allegation_text        30630 non-null  object
#  7   allegation_start_page  30630 non-null  int64
#  8   txt_file               30630 non-null  object
#  9   allegation_id          30630 non-null  object
# dtypes: int64(3), object(7)
# memory usage: 2.3+ MB

# %%
ref.loc[ref.complaint_meta.isna()]
# Out:
#                                                  pdf_url  \
# 137    https://sf.gov/sites/default/files/2023-03/Ope...
# 220    https://sf.gov/sites/default/files/2023-03/Ope...
# 295    https://sf.gov/sites/default/files/2023-04/Ope...
# 296    https://sf.gov/sites/default/files/2023-04/Ope...
# 365    https://sf.gov/sites/default/files/2023-04/Ope...
# ...                                                  ...
# 29441  https://wayback.archive-it.org/org-571/2023012...
# 29775  https://wayback.archive-it.org/org-571/2023012...
# 30050  https://wayback.archive-it.org/org-571/2023012...
# 30307  https://wayback.archive-it.org/org-571/2023012...
# 30629  https://wayback.archive-it.org/org-571/2023012...
#
#                                      pdf_file    fileid  complaint_no  \
# 137    output/pdfs/Openness_report_Jan_23.pdf  a1b401ae            69
# 220    output/pdfs/Openness_report_Feb_23.pdf  11fc09eb            36
# ...
